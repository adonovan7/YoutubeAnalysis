# %%
'''
Script to read in and clean data. Returns dataframe "videos" as
training/ test data and "df" as the data for predictions
'''
import pandas as pd; import os
import csv; import numpy as np
import re; import warnings
warnings.filterwarnings('ignore')

os.chdir('/Users/andiedonovan/myProjects/Youtube_Python_Project/AndiesBranch/') # change directory

df = pd.read_csv('data/data.csv', delimiter="@@@", skiprows=2, encoding='utf-8', engine='python')

# training data
okgo = pd.read_csv('data/OKGO.csv', delimiter=";", skiprows=2, encoding='latin-1', engine='python') # read in the data
trump = pd.read_csv('data/trump.csv', delimiter=",", skiprows=2, encoding='utf-8', error_bad_lines=False, engine='python')
swift = pd.read_csv('data/TaylorSwift.csv', delimiter=",", skiprows=2, nrows=180, encoding='utf-8', engine='python')
royal = pd.read_csv('data/RoyalWedding.csv', delimiter=",", skiprows=2, nrows=61, encoding='utf-8', engine='python')
paul = pd.read_csv('data/LoganPaul.csv', delimiter=",", skiprows=2, nrows=200, encoding='utf-8', engine='python')
blogs = pd.read_csv('data/Kagel.csv', delimiter=",", skiprows=2, encoding='latin-1', engine='python') # read in the data
tweets = pd.read_csv('data/twitter.csv', delimiter=",", skiprows=2, encoding='latin-1', engine='python') # read in the data

# clean dataframes
tweets = tweets.drop(['Topic', 'TweetId', "TweetDate"], axis = 1).dropna()
df.columns = ["comment", "label"]
df = df[["label", "comment"]]

def fix_cols(DF):
    DF = DF.iloc[:,:2]
    DF.columns = ["label", "comment"]
    return DF

okgo = fix_cols(okgo); trump = fix_cols(trump)
swift = fix_cols(swift); royal = fix_cols(royal)
paul = fix_cols(paul); tweets = fix_cols(tweets)
blogs = fix_cols(blogs); df = fix_cols(df)

# %%
# fix up tweets dataset
tweets.label = tweets.label.replace({'positive': '1.0', 'negative':'-1.0', 'neutral': '0.0', 'irrelevant': '0.0'}, regex=True)
tweets['label'] = pd.to_numeric(tweets['label'], errors='coerce')

# make one large dataframe from YouTube videos
videos = pd.concat([okgo, trump, swift, royal, paul], ignore_index=True)
videos = fix_cols(videos) # repetitive but for safe measures

# convert to string type
'''df["comment"]= df["comment"].astype(str)
videos["comment"]= videos["comment"].astype(str)
full["comment"]= full["comment"].astype(str)
'''

# make one large dataframe from all datasets including twitter and blogs
full = pd.concat([okgo, trump, swift, royal, paul, blogs, tweets], ignore_index=False)

df["comment"] = df["comment"].astype(str)
videos["comment"] = videos["comment"].astype(str)
full["comment"] = full["comment"].astype(str)

# removing non alphanumeric characters
def cleanerFn(b):
    for row in range(len(b)):
        line = b.loc[row, "comment"]
        b.loc[row,"comment"] = re.sub("[^a-zA-Z]", " ", line)
    return b

df = cleanerFn(df)
videos = cleanerFn(videos)

# %%
df.head(3)
len(df)
# Out:
# 80

# %%
range(1, len(df))
# Out:
# range(1, 80)

# %%
df.iloc[0, 1]
# Out:
# 'why the fuck does this look fake '

# %%
df
# Out:
#     label                                            comment
# 0     NaN                  why the fuck does this look fake
# 1     NaN                                        it so cool
# 2     NaN                                    Im so confused
# 3     NaN         Not really printers Just paper dispensers
# 4     NaN    Its like an INXS song in a Peter Gabriel video
# 5     NaN  How many times did they have to change the ink...
# 6     NaN                Dear Lord the cost of all that ink
# 7     NaN  Never noticed the finger spelling before So cool
# 8     NaN            I always watch these vids in art class
# 9     NaN                           Andy looks so puffed up
# 10    NaN                                               ASL
# 11    NaN                 You guys never disappoint Love iy
# 12    NaN  I wonder what it smelt like and how much heat ...
# 13    NaN                      Disgusting waste of material
# 14    NaN  Emma Mondaca it said they were recycled and gi...
# 15    NaN                  Damien Kulash almost slipped off
# 16    NaN                 Ok Go s music is all real Love it
# 17    NaN                                              Cool
# 18    NaN                                    Earth disaster
# 19    NaN  Paper is the least of the waste here guys And ...
# 20    NaN          Makes up for the rubbish music I suppose
# 21    NaN                  This might be my favorite of all
# 22    NaN  BOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO...
# 23    NaN  The best filmmakers alive today Real effects R...
# 24    NaN  It would have been better with Dunder Mifflin ...
# 25    NaN  How they come up with this shit is beyond my u...
# 26    NaN  how many printers had to be replaced in the ma...
# 27    NaN                                all that toner ink
# 28    NaN  Other people This is amazing music Me How do t...
# 29    NaN             So clever I love this video and song
# ..    ...                                                ...
# 50    NaN   Can I please have one or two of those printers
# 51    NaN             Where did the      and  k options go
# 52    NaN      OK GO  nigahiga  the most creative team ever
# 53    NaN        NEW DUNDERMIFFLIN PAPER COMPANY COMMERCIAL
# 54    NaN                    They give me hope for humanity
# 55    NaN  Anyone else wishing they had given away pages ...
# 56    NaN                             I just LOVE this band
# 57    NaN                             this is art i love it
# 58    NaN                                           lumayan
# 59    NaN  Does anybody else noticed that the man slipped...
# 60    NaN          This is incredible who orchestrated this
# 61    NaN  I still can t believe there s no editing what ...
# 62    NaN  ok but is nobody gonna talk about how good thi...
# 63    NaN  TF did I just watch every time I see a new OK ...
# 64    NaN  do you know what I could have did with that pa...
# 65    NaN                      ok go the elon musk of bands
# 66    NaN                              they are really cool
# 67    NaN   Cant believe all those printers actually worked
# 68    NaN          how am i just now seeing this perfection
# 69    NaN                                      it was great
# 70    NaN  Ill tell you something that doesnt exist Peopl...
# 71    NaN       So this why we have global warming I dig it
# 72    NaN                                      Precisavaaaa
# 73    NaN             a propaganda nao me deixa ter paz pqp
# 74    NaN                                                nan
# 75    NaN                        How many paper did it cost
# 76    NaN
# 77    NaN              Imagine if one of the printers broke
# 78    NaN                                                nan
# 79    NaN                                         Muito bom
#
# [80 rows x 2 columns]
